# %%
def multiplications_table(x,y):
    for x in range(30):
      print(x,"x",y,"=",x*y)

# %%
multiplications_table(1,34)
# Out:
# 0 x 34 = 0
# 1 x 34 = 34
# 2 x 34 = 68
# 3 x 34 = 102
# 4 x 34 = 136
# 5 x 34 = 170
# 6 x 34 = 204
# 7 x 34 = 238
# 8 x 34 = 272
# 9 x 34 = 306
# 10 x 34 = 340
# 11 x 34 = 374
# 12 x 34 = 408
# 13 x 34 = 442
# 14 x 34 = 476
# 15 x 34 = 510
# 16 x 34 = 544
# 17 x 34 = 578
# 18 x 34 = 612
# 19 x 34 = 646
# 20 x 34 = 680
# 21 x 34 = 714
# 22 x 34 = 748
# 23 x 34 = 782
# 24 x 34 = 816
# 25 x 34 = 850
# 26 x 34 = 884
# 27 x 34 = 918
# 28 x 34 = 952
# 29 x 34 = 986

# %%
def divisions(x,y):
  for x in range(1,31):
    print(x,"/",y,"=",y/x)

# %%
divisions(1,33)
# Out:
# 1 / 33 = 33.0
# 2 / 33 = 16.5
# 3 / 33 = 11.0
# 4 / 33 = 8.25
# 5 / 33 = 6.6
# 6 / 33 = 5.5
# 7 / 33 = 4.714285714285714
# 8 / 33 = 4.125
# 9 / 33 = 3.6666666666666665
# 10 / 33 = 3.3
# 11 / 33 = 3.0
# 12 / 33 = 2.75
# 13 / 33 = 2.5384615384615383
# 14 / 33 = 2.357142857142857
# 15 / 33 = 2.2
# 16 / 33 = 2.0625
# 17 / 33 = 1.9411764705882353
# 18 / 33 = 1.8333333333333333
# 19 / 33 = 1.736842105263158
# 20 / 33 = 1.65
# 21 / 33 = 1.5714285714285714
# 22 / 33 = 1.5
# 23 / 33 = 1.434782608695652
# 24 / 33 = 1.375
# 25 / 33 = 1.32
# 26 / 33 = 1.2692307692307692
# 27 / 33 = 1.2222222222222223
# 28 / 33 = 1.1785714285714286
# 29 / 33 = 1.1379310344827587
# 30 / 33 = 1.1

# %%
def exponents(x,y):
  for x in range(1,31):
    print(x,"**",y,"=",y**x)

# %%
exponents(1,29)
# Out:
# 1 ** 29 = 29
# 2 ** 29 = 841
# 3 ** 29 = 24389
# 4 ** 29 = 707281
# 5 ** 29 = 20511149
# 6 ** 29 = 594823321
# 7 ** 29 = 17249876309
# 8 ** 29 = 500246412961
# 9 ** 29 = 14507145975869
# 10 ** 29 = 420707233300201
# 11 ** 29 = 12200509765705829
# 12 ** 29 = 353814783205469041
# 13 ** 29 = 10260628712958602189
# 14 ** 29 = 297558232675799463481
# 15 ** 29 = 8629188747598184440949
# 16 ** 29 = 250246473680347348787521
# 17 ** 29 = 7257147736730073114838109
# 18 ** 29 = 210457284365172120330305161
# 19 ** 29 = 6103261246589991489578849669
# 20 ** 29 = 176994576151109753197786640401
# 21 ** 29 = 5132842708382182842735812571629
# 22 ** 29 = 148852438543083302439338564577241
# 23 ** 29 = 4316720717749415770740818372739989
# 24 ** 29 = 125184900814733057351483732809459681
# 25 ** 29 = 3630362123627258663193028251474330749
# 26 ** 29 = 105280501585190501232597819292755591721
# 27 ** 29 = 3053134545970524535745336759489912159909
# 28 ** 29 = 88540901833145211536614766025207452637361
# ...
